# %% [markdown]
# ## Setup

# %%
import warnings
warnings.filterwarnings('ignore')

import numpy as np
import pandas as pd
import seaborn as sn

from keras.datasets import mnist
import tensorflow.keras as kb
from tensorflow.keras import backend
import tensorflow as tf

from keras.utils import to_categorical
from keras.callbacks import EarlyStopping
from keras.preprocessing.image import ImageDataGenerator


from matplotlib import pyplot as plt
from plotnine import *

from sklearn.metrics import mean_squared_error, mean_absolute_error, roc_auc_score, r2_score

from sklearn.linear_model import LinearRegression # Linear Regression Model
from sklearn.preprocessing import StandardScaler #Z-score variables

from sklearn.model_selection import train_test_split # simple TT split cv
from sklearn.model_selection import KFold # k-fold cv
from sklearn.model_selection import LeaveOneOut #LOO cv

# %% [markdown]
# ## Background of Data
#
# Images are not in dcm format, the images are in jpg or png to fit the model
#
# Data contain 3 lung cancer types which are Adenocarcinoma, Large cell carcinoma, Squamous cell carcinoma, and 1 folder for the normal cell
#
# Data folder is the main folder that contain all the step folders
# inside Data folder are test , train , valid
#
# - test represent testing set
# - train represent training set
# - valid represent validation set
# - training set is 70%
# - testing set is 20%
# - validation set is 10%
#
# Adenocarcinoma
# - Adenocarcinoma of the lung: Lung adenocarcinoma is the most common form of lung cancer accounting for 30 percent of all cases overall and about 40 percent
# of all non-small cell lung cancer occurrences
# - Adenocarcinomas are found in several common cancers, including breast, prostate and colorectal
# - Adenocarcinomas of the lung are found in the outer region of the lung
# in glands that secrete mucus and help us breathe
# - Symptoms include coughing, hoarseness, weight loss, and weakness.
#
# Large cell carcinoma
# - Large-cell undifferentiated carcinoma: Large-cell undifferentiated carcinoma lung cancer grows and spreads quickly and can be found anywhere in the lung
# - This type of lung cancer usually accounts for 10 to 15 percent of all cases of NSCLC
# - Large-cell undifferentiated carcinoma tends to grow and spread quickly
#
# Squamous cell carcinoma
# - Squamous cell: This type of lung cancer is found centrally in the lung, where the larger bronchi join the trachea to the lung,or in one of the main airway branches
# - Squamous cell lung cancer is responsible for about 30 percent of all non-small
# cell lung cancers, and is generally linked to smoking.
#
# And the last folder is the normal CT-Scan images

# %% [markdown]
# ## Reading in and Setting Up Data

# %%
# make kaggle directory
# !mkdir ~/.kaggle

# move kaggle.json to hidden kaggle folder
# !cp kaggle.json ~/.kaggle/

# change permissions on file
# !chmod 600 ~/.kaggle/kaggle.json

# download zipped data
# !kaggle datasets download -d mohamedhanyyy/chest-ctscan-images
# Out:
# Downloading chest-ctscan-images.zip to /content
#  99% 118M/119M [00:00<00:00, 202MB/s]
# 100% 119M/119M [00:00<00:00, 172MB/s]

# %%
# !unzip -qq chest-ctscan-images.zip

# %%
train_dir = "./Data/train"
test_dir = "./Data/test"
val_dir = "./Data/valid"

# %%
batch_size = 32
image_width = 150
image_height = 150

train_ds = tf.keras.utils.image_dataset_from_directory(
  train_dir, # file path
  seed = 393, # seed
  image_size = (image_width, image_height), # size of image
  batch_size = batch_size, # number of images per batch
  labels ='inferred',  # Use inferred labels from subdirectories
  label_mode ='categorical') # One-hot encode the labels
# Out:
# Found 613 files belonging to 4 classes.

# %%
val_ds = tf.keras.utils.image_dataset_from_directory(
  val_dir, # file path
  seed = 393, # seed
  image_size = (image_width, image_height), # size of image
  batch_size = batch_size, # number of images per batch
  labels ='inferred',  # Use inferred labels from subdirectories
  label_mode ='categorical') # One-hot encode the labels
# Out:
# Found 72 files belonging to 4 classes.

# %%
test_ds = tf.keras.utils.image_dataset_from_directory(
  test_dir, # file path
  seed = 393, # seed
  image_size = (image_width, image_height), # size of image
  batch_size = batch_size, # number of images per batch
  labels ='inferred',  # Use inferred labels from subdirectories
  label_mode ='categorical') # One-hot encode the labels
# Out:
# Found 315 files belonging to 4 classes.

# %% [markdown]
# ## Creating Model

# %%
early_stopping = EarlyStopping(monitor = 'val_loss', patience = 5, restore_best_weights = True)

model = kb.Sequential()

model.add(kb.layers.Conv2D(32, (3, 3), activation = 'relu', input_shape = (image_width, image_height, 3)))
model.add(kb.layers.BatchNormalization())
model.add(kb.layers.MaxPooling2D((2, 2)))

model.add(kb.layers.Conv2D(64, (3, 3), activation = 'relu', kernel_regularizer = kb.regularizers.l2()))
model.add(kb.layers.BatchNormalization())
model.add(kb.layers.MaxPooling2D((2, 2)))

model.add(kb.layers.Conv2D(128, (3, 3), activation = 'relu', kernel_regularizer = kb.regularizers.l2()))
model.add(kb.layers.BatchNormalization())
model.add(kb.layers.MaxPooling2D((2, 2)))

model.add(kb.layers.Conv2D(256, (3, 3), activation = 'relu', kernel_regularizer = kb.regularizers.l2()))
model.add(kb.layers.BatchNormalization())
model.add(kb.layers.MaxPooling2D((2, 2)))

model.add(kb.layers.Conv2D(512, (3, 3), activation = 'relu', kernel_regularizer = kb.regularizers.l2()))
model.add(kb.layers.BatchNormalization())
model.add(kb.layers.MaxPooling2D((2, 2)))

model.add(kb.layers.Flatten())

model.add(kb.layers.Dense(256, activation = 'relu', kernel_regularizer = kb.regularizers.l2()))
model.add(kb.layers.BatchNormalization())

model.add(kb.layers.Dense(128, activation = 'relu', kernel_regularizer = kb.regularizers.l2()))
model.add(kb.layers.Dropout(0.5))

model.add(kb.layers.Dense(64, activation = 'relu', kernel_regularizer = kb.regularizers.l2()))
model.add(kb.layers.Dropout(0.3))

model.add(kb.layers.Dense(32, activation = 'relu', kernel_regularizer = kb.regularizers.l2()))

model.add(kb.layers.Dense(4, activation = 'softmax'))

model.compile(loss = 'categorical_crossentropy', optimizer = kb.optimizers.Adam(learning_rate = 0.0001), metrics = ['accuracy'])

# %%
# fit the model
history = model.fit(
    train_ds,                         # training data
    epochs = 100,
    validation_data = (val_ds),       # validation data
    callbacks = [early_stopping]
)
# Out:
# Epoch 1/100
# 20/20 [==============================] - 54s 2s/step - loss: 15.3118 - accuracy: 0.3605 - val_loss: 15.3069 - val_accuracy: 0.1806
# Epoch 2/100
# 20/20 [==============================] - 49s 2s/step - loss: 14.9519 - accuracy: 0.4812 - val_loss: 15.1287 - val_accuracy: 0.1806
# Epoch 3/100
# 20/20 [==============================] - 50s 2s/step - loss: 14.7977 - accuracy: 0.5661 - val_loss: 15.0027 - val_accuracy: 0.1806
# Epoch 4/100
# 20/20 [==============================] - 48s 2s/step - loss: 14.5792 - accuracy: 0.6166 - val_loss: 14.8803 - val_accuracy: 0.1944
# Epoch 5/100
# 20/20 [==============================] - 50s 2s/step - loss: 14.3850 - accuracy: 0.6558 - val_loss: 14.7536 - val_accuracy: 0.1944
# Epoch 6/100
# 20/20 [==============================] - 50s 2s/step - loss: 14.2534 - accuracy: 0.6786 - val_loss: 14.5974 - val_accuracy: 0.3194
# Epoch 7/100
# 20/20 [==============================] - 48s 2s/step - loss: 14.1180 - accuracy: 0.6933 - val_loss: 14.4461 - val_accuracy: 0.4722
# Epoch 8/100
# 20/20 [==============================] - 49s 2s/step - loss: 13.9725 - accuracy: 0.7325 - val_loss: 14.3111 - val_accuracy: 0.5833
# Epoch 9/100
# 20/20 [==============================] - 49s 2s/step - loss: 13.8255 - accuracy: 0.7341 - val_loss: 14.1707 - val_accuracy: 0.6111
# Epoch 10/100
# 20/20 [==============================] - 48s 2s/step - loss: 13.6546 - accuracy: 0.7749 - val_loss: 14.0296 - val_accuracy: 0.6389
# Epoch 11/100
# 20/20 [==============================] - 48s 2s/step - loss: 13.5535 - accuracy: 0.7912 - val_loss: 13.9249 - val_accuracy: 0.5972
# Epoch 12/100
# 20/20 [==============================] - 51s 2s/step - loss: 13.4028 - accuracy: 0.8271 - val_loss: 13.8001 - val_accuracy: 0.5972
# Epoch 13/100
# 20/20 [==============================] - 49s 2s/step - loss: 13.3003 - accuracy: 0.8108 - val_loss: 13.6714 - val_accuracy: 0.6111
# Epoch 14/100
# 20/20 [==============================] - 51s 3s/step - loss: 13.1151 - accuracy: 0.8303 - val_loss: 13.5376 - val_accuracy: 0.5556
# Epoch 15/100
# 20/20 [==============================] - 51s 3s/step - loss: 12.9486 - accuracy: 0.8825 - val_loss: 13.3680 - val_accuracy: 0.6250
# Epoch 16/100
# 20/20 [==============================] - 49s 2s/step - loss: 12.8322 - accuracy: 0.8940 - val_loss: 13.2074 - val_accuracy: 0.7083
# Epoch 17/100
# 20/20 [==============================] - 51s 2s/step - loss: 12.6699 - accuracy: 0.8940 - val_loss: 13.0737 - val_accuracy: 0.6944
# Epoch 18/100
# 20/20 [==============================] - 50s 2s/step - loss: 12.5344 - accuracy: 0.9103 - val_loss: 12.9474 - val_accuracy: 0.7361
# Epoch 19/100
# 20/20 [==============================] - 49s 2s/step - loss: 12.3849 - accuracy: 0.9250 - val_loss: 12.8556 - val_accuracy: 0.7361
# Epoch 20/100
# 20/20 [==============================] - 50s 2s/step - loss: 12.2770 - accuracy: 0.9299 - val_loss: 12.6671 - val_accuracy: 0.7639
# Epoch 21/100
# 20/20 [==============================] - 48s 2s/step - loss: 12.1191 - accuracy: 0.9511 - val_loss: 12.5415 - val_accuracy: 0.7639
# Epoch 22/100
# 20/20 [==============================] - 49s 2s/step - loss: 12.0085 - accuracy: 0.9527 - val_loss: 12.4206 - val_accuracy: 0.7361
# Epoch 23/100
# 20/20 [==============================] - 49s 2s/step - loss: 11.8614 - accuracy: 0.9543 - val_loss: 12.2905 - val_accuracy: 0.7778
# Epoch 24/100
# 20/20 [==============================] - 49s 2s/step - loss: 11.7485 - accuracy: 0.9657 - val_loss: 12.2598 - val_accuracy: 0.7361
# Epoch 25/100
# 20/20 [==============================] - 49s 2s/step - loss: 11.6766 - accuracy: 0.9380 - val_loss: 12.1061 - val_accuracy: 0.7361
# Epoch 26/100
# 20/20 [==============================] - 50s 2s/step - loss: 11.5564 - accuracy: 0.9608 - val_loss: 11.9750 - val_accuracy: 0.7639
# Epoch 27/100
# 20/20 [==============================] - 49s 2s/step - loss: 11.4167 - accuracy: 0.9641 - val_loss: 11.8213 - val_accuracy: 0.8056
# Epoch 28/100
# 20/20 [==============================] - 49s 2s/step - loss: 11.2837 - accuracy: 0.9706 - val_loss: 11.7122 - val_accuracy: 0.7778
# Epoch 29/100
# 20/20 [==============================] - 52s 3s/step - loss: 11.1642 - accuracy: 0.9723 - val_loss: 11.6279 - val_accuracy: 0.7917
# Epoch 30/100
# 20/20 [==============================] - 55s 3s/step - loss: 11.0734 - accuracy: 0.9706 - val_loss: 11.5946 - val_accuracy: 0.7222
# Epoch 31/100
# 20/20 [==============================] - 55s 3s/step - loss: 11.0415 - accuracy: 0.9511 - val_loss: 11.4716 - val_accuracy: 0.7500
# Epoch 32/100
# 20/20 [==============================] - 56s 3s/step - loss: 10.9439 - accuracy: 0.9641 - val_loss: 11.3801 - val_accuracy: 0.7778
# Epoch 33/100
# 20/20 [==============================] - 55s 3s/step - loss: 10.8000 - accuracy: 0.9788 - val_loss: 11.3188 - val_accuracy: 0.7917
# Epoch 34/100
# 20/20 [==============================] - 58s 3s/step - loss: 10.7258 - accuracy: 0.9608 - val_loss: 11.1738 - val_accuracy: 0.7778
# Epoch 35/100
# 20/20 [==============================] - 54s 3s/step - loss: 10.6009 - accuracy: 0.9739 - val_loss: 11.0799 - val_accuracy: 0.7917
# Epoch 36/100
# 20/20 [==============================] - 62s 3s/step - loss: 10.4829 - accuracy: 0.9755 - val_loss: 11.0096 - val_accuracy: 0.8333
# Epoch 37/100
# 20/20 [==============================] - 65s 3s/step - loss: 10.3845 - accuracy: 0.9821 - val_loss: 10.9262 - val_accuracy: 0.8056
# Epoch 38/100
# 20/20 [==============================] - 66s 3s/step - loss: 10.3210 - accuracy: 0.9739 - val_loss: 10.8327 - val_accuracy: 0.7917
# Epoch 39/100
# 20/20 [==============================] - 63s 3s/step - loss: 10.1901 - accuracy: 0.9837 - val_loss: 10.6880 - val_accuracy: 0.8194
# Epoch 40/100
# 20/20 [==============================] - 66s 3s/step - loss: 10.0993 - accuracy: 0.9821 - val_loss: 10.6492 - val_accuracy: 0.7778
# Epoch 41/100
# 20/20 [==============================] - 65s 3s/step - loss: 10.0021 - accuracy: 0.9837 - val_loss: 10.6750 - val_accuracy: 0.7639
# Epoch 42/100
# 20/20 [==============================] - 53s 3s/step - loss: 9.8830 - accuracy: 0.9886 - val_loss: 10.4911 - val_accuracy: 0.8194
# Epoch 43/100
# 20/20 [==============================] - 50s 2s/step - loss: 9.7830 - accuracy: 0.9935 - val_loss: 10.4441 - val_accuracy: 0.7917
# Epoch 44/100
# 20/20 [==============================] - 53s 3s/step - loss: 9.6978 - accuracy: 0.9902 - val_loss: 10.3610 - val_accuracy: 0.7639
# Epoch 45/100
# 20/20 [==============================] - 57s 3s/step - loss: 9.6340 - accuracy: 0.9804 - val_loss: 10.1974 - val_accuracy: 0.8056
# Epoch 46/100
# 20/20 [==============================] - 49s 2s/step - loss: 9.5944 - accuracy: 0.9772 - val_loss: 10.2403 - val_accuracy: 0.7222
# Epoch 47/100
# 20/20 [==============================] - 50s 2s/step - loss: 9.4582 - accuracy: 0.9804 - val_loss: 10.0668 - val_accuracy: 0.7778
# Epoch 48/100
# 20/20 [==============================] - 51s 3s/step - loss: 9.3824 - accuracy: 0.9837 - val_loss: 10.0408 - val_accuracy: 0.7778
# Epoch 49/100
# 20/20 [==============================] - 47s 2s/step - loss: 9.2872 - accuracy: 0.9902 - val_loss: 9.9118 - val_accuracy: 0.8194
# Epoch 50/100
# 20/20 [==============================] - 51s 2s/step - loss: 9.2003 - accuracy: 0.9886 - val_loss: 9.8097 - val_accuracy: 0.8056
# Epoch 51/100
# 20/20 [==============================] - 50s 2s/step - loss: 9.1208 - accuracy: 0.9821 - val_loss: 9.7339 - val_accuracy: 0.7917
# Epoch 52/100
# 20/20 [==============================] - 51s 3s/step - loss: 9.0607 - accuracy: 0.9804 - val_loss: 9.6998 - val_accuracy: 0.8333
# Epoch 53/100
# 20/20 [==============================] - 50s 2s/step - loss: 8.9794 - accuracy: 0.9821 - val_loss: 9.5818 - val_accuracy: 0.7222
# Epoch 54/100
# 20/20 [==============================] - 51s 3s/step - loss: 8.9260 - accuracy: 0.9739 - val_loss: 9.6298 - val_accuracy: 0.6944
# Epoch 55/100
# 20/20 [==============================] - 49s 2s/step - loss: 8.8820 - accuracy: 0.9592 - val_loss: 9.7873 - val_accuracy: 0.6111
# Epoch 56/100
# 20/20 [==============================] - 47s 2s/step - loss: 8.7978 - accuracy: 0.9690 - val_loss: 9.4238 - val_accuracy: 0.7361
# Epoch 57/100
# 20/20 [==============================] - 51s 2s/step - loss: 8.6886 - accuracy: 0.9821 - val_loss: 9.2734 - val_accuracy: 0.7639
# Epoch 58/100
# 20/20 [==============================] - 48s 2s/step - loss: 8.5933 - accuracy: 0.9853 - val_loss: 9.2542 - val_accuracy: 0.7222
# Epoch 59/100
# 20/20 [==============================] - 49s 2s/step - loss: 8.5519 - accuracy: 0.9837 - val_loss: 9.2107 - val_accuracy: 0.7639
# Epoch 60/100
# 20/20 [==============================] - 49s 2s/step - loss: 8.4484 - accuracy: 0.9935 - val_loss: 9.1235 - val_accuracy: 0.7778
# Epoch 61/100
# 20/20 [==============================] - 51s 2s/step - loss: 8.4019 - accuracy: 0.9788 - val_loss: 9.1099 - val_accuracy: 0.7639
# Epoch 62/100
# 20/20 [==============================] - 48s 2s/step - loss: 8.3615 - accuracy: 0.9739 - val_loss: 8.8879 - val_accuracy: 0.7639
# Epoch 63/100
# 20/20 [==============================] - 49s 2s/step - loss: 8.2639 - accuracy: 0.9837 - val_loss: 8.8277 - val_accuracy: 0.7639
# Epoch 64/100
# 20/20 [==============================] - 50s 2s/step - loss: 8.2034 - accuracy: 0.9853 - val_loss: 8.7824 - val_accuracy: 0.7500
# Epoch 65/100
# 20/20 [==============================] - 48s 2s/step - loss: 8.1247 - accuracy: 0.9788 - val_loss: 8.7419 - val_accuracy: 0.7639
# Epoch 66/100
# 20/20 [==============================] - 48s 2s/step - loss: 8.0199 - accuracy: 0.9984 - val_loss: 8.6662 - val_accuracy: 0.7639
# Epoch 67/100
# 20/20 [==============================] - 49s 2s/step - loss: 7.9557 - accuracy: 0.9935 - val_loss: 8.6142 - val_accuracy: 0.7917
# Epoch 68/100
# 20/20 [==============================] - 49s 2s/step - loss: 7.8941 - accuracy: 0.9853 - val_loss: 8.6851 - val_accuracy: 0.7778
# Epoch 69/100
# 20/20 [==============================] - 49s 2s/step - loss: 7.8171 - accuracy: 0.9935 - val_loss: 8.8045 - val_accuracy: 0.7083
# Epoch 70/100
# 20/20 [==============================] - 50s 2s/step - loss: 7.7424 - accuracy: 0.9951 - val_loss: 8.6051 - val_accuracy: 0.7083
# Epoch 71/100
# 20/20 [==============================] - 48s 2s/step - loss: 7.6786 - accuracy: 0.9967 - val_loss: 8.4833 - val_accuracy: 0.7639
# Epoch 72/100
# 20/20 [==============================] - 50s 2s/step - loss: 7.6168 - accuracy: 0.9918 - val_loss: 8.4619 - val_accuracy: 0.7778
# Epoch 73/100
# 20/20 [==============================] - 48s 2s/step - loss: 7.5499 - accuracy: 0.9918 - val_loss: 8.3302 - val_accuracy: 0.7222
# Epoch 74/100
# 20/20 [==============================] - 49s 2s/step - loss: 7.5205 - accuracy: 0.9788 - val_loss: 8.2639 - val_accuracy: 0.7778
# Epoch 75/100
# 20/20 [==============================] - 49s 2s/step - loss: 7.4491 - accuracy: 0.9804 - val_loss: 8.5246 - val_accuracy: 0.7083
# Epoch 76/100
# 20/20 [==============================] - 55s 3s/step - loss: 7.4074 - accuracy: 0.9772 - val_loss: 8.2795 - val_accuracy: 0.7083
# Epoch 77/100
# 20/20 [==============================] - 53s 3s/step - loss: 7.3591 - accuracy: 0.9755 - val_loss: 8.1751 - val_accuracy: 0.7500
# Epoch 78/100
# 20/20 [==============================] - 52s 3s/step - loss: 7.2676 - accuracy: 0.9869 - val_loss: 8.0488 - val_accuracy: 0.8056
# Epoch 79/100
# 20/20 [==============================] - 55s 3s/step - loss: 7.1880 - accuracy: 0.9902 - val_loss: 8.0532 - val_accuracy: 0.7639
# Epoch 80/100
# 20/20 [==============================] - 53s 3s/step - loss: 7.1291 - accuracy: 0.9886 - val_loss: 8.0020 - val_accuracy: 0.7639
# Epoch 81/100
# 20/20 [==============================] - 57s 3s/step - loss: 7.0467 - accuracy: 0.9935 - val_loss: 7.9166 - val_accuracy: 0.7639
# Epoch 82/100
# 20/20 [==============================] - 53s 3s/step - loss: 6.9996 - accuracy: 0.9935 - val_loss: 7.8643 - val_accuracy: 0.7500
# Epoch 83/100
# 20/20 [==============================] - 58s 3s/step - loss: 6.9290 - accuracy: 0.9935 - val_loss: 7.8054 - val_accuracy: 0.7917
# Epoch 84/100
# 20/20 [==============================] - 52s 3s/step - loss: 6.8793 - accuracy: 0.9853 - val_loss: 7.8292 - val_accuracy: 0.7778
# Epoch 85/100
# 20/20 [==============================] - 54s 3s/step - loss: 6.8354 - accuracy: 0.9902 - val_loss: 7.8860 - val_accuracy: 0.7500
# Epoch 86/100
# 20/20 [==============================] - 52s 2s/step - loss: 6.7467 - accuracy: 0.9951 - val_loss: 7.6232 - val_accuracy: 0.7639
# Epoch 87/100
# 20/20 [==============================] - 52s 3s/step - loss: 6.6752 - accuracy: 0.9967 - val_loss: 7.5257 - val_accuracy: 0.7778
# Epoch 88/100
# 20/20 [==============================] - 52s 3s/step - loss: 6.6142 - accuracy: 0.9935 - val_loss: 7.5047 - val_accuracy: 0.7639
# Epoch 89/100
# 20/20 [==============================] - 52s 3s/step - loss: 6.5565 - accuracy: 0.9951 - val_loss: 7.4174 - val_accuracy: 0.7917
# Epoch 90/100
# 20/20 [==============================] - 52s 3s/step - loss: 6.4941 - accuracy: 0.9935 - val_loss: 7.3076 - val_accuracy: 0.7917
# Epoch 91/100
# 20/20 [==============================] - 53s 3s/step - loss: 6.4271 - accuracy: 0.9967 - val_loss: 7.2437 - val_accuracy: 0.7917
# Epoch 92/100
# 20/20 [==============================] - 54s 3s/step - loss: 6.3686 - accuracy: 0.9967 - val_loss: 7.2114 - val_accuracy: 0.7639
# Epoch 93/100
# 20/20 [==============================] - 49s 2s/step - loss: 6.3162 - accuracy: 0.9951 - val_loss: 7.1786 - val_accuracy: 0.7639
# Epoch 94/100
# 20/20 [==============================] - 48s 2s/step - loss: 6.2851 - accuracy: 0.9886 - val_loss: 7.7238 - val_accuracy: 0.6667
# Epoch 95/100
# 20/20 [==============================] - 50s 2s/step - loss: 6.2147 - accuracy: 0.9918 - val_loss: 7.2894 - val_accuracy: 0.7222
# Epoch 96/100
# 20/20 [==============================] - 47s 2s/step - loss: 6.1455 - accuracy: 0.9984 - val_loss: 7.1086 - val_accuracy: 0.7639
# Epoch 97/100
# 20/20 [==============================] - 50s 2s/step - loss: 6.0860 - accuracy: 0.9935 - val_loss: 7.0688 - val_accuracy: 0.7500
# Epoch 98/100
# 20/20 [==============================] - 48s 2s/step - loss: 6.0263 - accuracy: 0.9967 - val_loss: 6.9947 - val_accuracy: 0.7639
# Epoch 99/100
# 20/20 [==============================] - 50s 2s/step - loss: 5.9668 - accuracy: 0.9967 - val_loss: 6.8704 - val_accuracy: 0.7778
# Epoch 100/100
# 20/20 [==============================] - 49s 2s/step - loss: 5.9187 - accuracy: 0.9918 - val_loss: 6.7208 - val_accuracy: 0.7639

# %%
plt.plot(history.history["loss"])
plt.plot(history.history["val_loss"])
plt.title("Model Categorical Cross Entropy")
plt.ylabel("Categorical Cross Entropy")
plt.xlabel("Epochs")
plt.legend(["train", "validation"], loc = "upper left")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.plot(history.history["accuracy"])
plt.plot(history.history["val_accuracy"])
plt.title("Model Accuracy")
plt.ylabel("Accuracy")
plt.xlabel("Epochs")
plt.legend(["train", "validation"], loc = "upper left")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ## Trying a Simpler Model

# %%
early_stopping = EarlyStopping(monitor = 'val_loss', patience = 5, restore_best_weights = True)

model2 = kb.Sequential()

model2.add(kb.layers.Conv2D(32, (3, 3), activation = 'relu', input_shape = (image_width, image_height, 3)))
model2.add(kb.layers.BatchNormalization())
model2.add(kb.layers.MaxPooling2D((2, 2)))

model2.add(kb.layers.Conv2D(64, (3, 3), activation = 'relu', kernel_regularizer = kb.regularizers.l2()))
model2.add(kb.layers.BatchNormalization())
model2.add(kb.layers.MaxPooling2D((2, 2)))

model2.add(kb.layers.Conv2D(128, (3, 3), activation = 'relu', kernel_regularizer = kb.regularizers.l2()))
model2.add(kb.layers.BatchNormalization())
model2.add(kb.layers.MaxPooling2D((2, 2)))

model2.add(kb.layers.Conv2D(128, (3, 3), activation = 'relu', kernel_regularizer = kb.regularizers.l2()))
model2.add(kb.layers.BatchNormalization())
model2.add(kb.layers.MaxPooling2D((2, 2)))

model2.add(kb.layers.Conv2D(256, (3, 3), activation = 'relu', kernel_regularizer = kb.regularizers.l2()))
model2.add(kb.layers.BatchNormalization())
model2.add(kb.layers.MaxPooling2D((2, 2)))

model2.add(kb.layers.Flatten())

model2.add(kb.layers.Dense(256, activation = 'relu', kernel_regularizer = kb.regularizers.l2()))
model2.add(kb.layers.BatchNormalization())

model2.add(kb.layers.Dense(128, activation = 'relu', kernel_regularizer = kb.regularizers.l2()))
model2.add(kb.layers.Dropout(0.5))

model2.add(kb.layers.Dense(64, activation = 'relu', kernel_regularizer = kb.regularizers.l2()))
model2.add(kb.layers.Dropout(0.3))

model2.add(kb.layers.Dense(32, activation = 'relu', kernel_regularizer = kb.regularizers.l2()))

model2.add(kb.layers.Dense(4, activation = 'softmax'))

model2.compile(loss = 'categorical_crossentropy', optimizer = kb.optimizers.Adam(learning_rate = 0.0001), metrics = ['accuracy'])

# %%
# fit the model
history = model2.fit(
    train_ds,                         # training data
    epochs = 100,
    validation_data = (val_ds),       # validation data
    callbacks = [early_stopping]
)
# Out:
# Epoch 1/100
# 20/20 [==============================] - 54s 3s/step - loss: 10.3013 - accuracy: 0.8972 - val_loss: 10.7119 - val_accuracy: 0.6944
# Epoch 2/100
# 20/20 [==============================] - 43s 2s/step - loss: 10.2426 - accuracy: 0.8972 - val_loss: 10.6129 - val_accuracy: 0.7222
# Epoch 3/100
# 20/20 [==============================] - 42s 2s/step - loss: 10.1175 - accuracy: 0.9233 - val_loss: 10.5492 - val_accuracy: 0.7083
# Epoch 4/100
# 20/20 [==============================] - 45s 2s/step - loss: 10.0374 - accuracy: 0.9168 - val_loss: 10.4844 - val_accuracy: 0.7083
# Epoch 5/100
# 20/20 [==============================] - 43s 2s/step - loss: 9.9904 - accuracy: 0.9135 - val_loss: 10.3738 - val_accuracy: 0.7778
# Epoch 6/100
# 20/20 [==============================] - 44s 2s/step - loss: 9.8749 - accuracy: 0.9299 - val_loss: 10.3747 - val_accuracy: 0.6944
# Epoch 7/100
# 20/20 [==============================] - 44s 2s/step - loss: 9.8348 - accuracy: 0.9119 - val_loss: 10.2509 - val_accuracy: 0.7222
# Epoch 8/100
# 20/20 [==============================] - 44s 2s/step - loss: 9.7084 - accuracy: 0.9511 - val_loss: 10.1746 - val_accuracy: 0.7500
# Epoch 9/100
# 20/20 [==============================] - 42s 2s/step - loss: 9.6077 - accuracy: 0.9608 - val_loss: 10.1098 - val_accuracy: 0.7500
# Epoch 10/100
# 20/20 [==============================] - 43s 2s/step - loss: 9.5289 - accuracy: 0.9543 - val_loss: 10.1038 - val_accuracy: 0.7361
# Epoch 11/100
# 20/20 [==============================] - 45s 2s/step - loss: 9.4819 - accuracy: 0.9462 - val_loss: 9.9676 - val_accuracy: 0.7083
# Epoch 12/100
# 20/20 [==============================] - 44s 2s/step - loss: 9.3961 - accuracy: 0.9625 - val_loss: 9.9063 - val_accuracy: 0.7500
# Epoch 13/100
# 20/20 [==============================] - 44s 2s/step - loss: 9.2886 - accuracy: 0.9739 - val_loss: 9.8121 - val_accuracy: 0.7361
# Epoch 14/100
# 20/20 [==============================] - 42s 2s/step - loss: 9.2595 - accuracy: 0.9560 - val_loss: 9.7958 - val_accuracy: 0.7222
# Epoch 15/100
# 20/20 [==============================] - 44s 2s/step - loss: 9.2029 - accuracy: 0.9576 - val_loss: 9.8022 - val_accuracy: 0.6944
# Epoch 16/100
# 20/20 [==============================] - 45s 2s/step - loss: 9.1269 - accuracy: 0.9560 - val_loss: 9.7428 - val_accuracy: 0.7222
# Epoch 17/100
# 20/20 [==============================] - 43s 2s/step - loss: 9.0357 - accuracy: 0.9690 - val_loss: 9.6884 - val_accuracy: 0.7222
# Epoch 18/100
# 20/20 [==============================] - 44s 2s/step - loss: 8.9721 - accuracy: 0.9755 - val_loss: 9.5828 - val_accuracy: 0.7083
# Epoch 19/100
# 20/20 [==============================] - 45s 2s/step - loss: 8.8713 - accuracy: 0.9739 - val_loss: 9.4664 - val_accuracy: 0.6806
# Epoch 20/100
# 20/20 [==============================] - 44s 2s/step - loss: 8.8080 - accuracy: 0.9804 - val_loss: 9.3632 - val_accuracy: 0.7361
# Epoch 21/100
# 20/20 [==============================] - 42s 2s/step - loss: 8.7142 - accuracy: 0.9935 - val_loss: 9.2752 - val_accuracy: 0.7222
# Epoch 22/100
# 20/20 [==============================] - 43s 2s/step - loss: 8.6430 - accuracy: 0.9918 - val_loss: 9.1978 - val_accuracy: 0.7500
# Epoch 23/100
# 20/20 [==============================] - 45s 2s/step - loss: 8.6154 - accuracy: 0.9755 - val_loss: 9.0597 - val_accuracy: 0.7639
# Epoch 24/100
# 20/20 [==============================] - 43s 2s/step - loss: 8.5326 - accuracy: 0.9935 - val_loss: 9.0187 - val_accuracy: 0.7639
# Epoch 25/100
# 20/20 [==============================] - 44s 2s/step - loss: 8.4544 - accuracy: 0.9886 - val_loss: 9.0023 - val_accuracy: 0.7222
# Epoch 26/100
# 20/20 [==============================] - 43s 2s/step - loss: 8.4118 - accuracy: 0.9821 - val_loss: 8.9512 - val_accuracy: 0.7222
# Epoch 27/100
# 20/20 [==============================] - 45s 2s/step - loss: 8.3209 - accuracy: 0.9918 - val_loss: 8.9350 - val_accuracy: 0.7639
# Epoch 28/100
# 20/20 [==============================] - 43s 2s/step - loss: 8.2779 - accuracy: 0.9853 - val_loss: 8.9192 - val_accuracy: 0.7222
# Epoch 29/100
# 20/20 [==============================] - 45s 2s/step - loss: 8.1965 - accuracy: 0.9935 - val_loss: 8.8756 - val_accuracy: 0.7639
# Epoch 30/100
# 20/20 [==============================] - 44s 2s/step - loss: 8.1731 - accuracy: 0.9788 - val_loss: 8.7957 - val_accuracy: 0.7222
# Epoch 31/100
# 20/20 [==============================] - 44s 2s/step - loss: 8.1052 - accuracy: 0.9772 - val_loss: 8.8507 - val_accuracy: 0.7500
# Epoch 32/100
# 20/20 [==============================] - 43s 2s/step - loss: 8.0792 - accuracy: 0.9755 - val_loss: 8.7264 - val_accuracy: 0.7222
# Epoch 33/100
# 20/20 [==============================] - 43s 2s/step - loss: 8.0027 - accuracy: 0.9869 - val_loss: 8.7631 - val_accuracy: 0.6944
# Epoch 34/100
# 20/20 [==============================] - 45s 2s/step - loss: 7.9623 - accuracy: 0.9755 - val_loss: 8.7818 - val_accuracy: 0.6944
# Epoch 35/100
# 20/20 [==============================] - 43s 2s/step - loss: 7.8741 - accuracy: 0.9788 - val_loss: 8.7311 - val_accuracy: 0.7083
# Epoch 36/100
# 20/20 [==============================] - 43s 2s/step - loss: 7.8097 - accuracy: 0.9886 - val_loss: 8.6019 - val_accuracy: 0.7500
# Epoch 37/100
# 20/20 [==============================] - 43s 2s/step - loss: 7.7472 - accuracy: 0.9902 - val_loss: 8.4609 - val_accuracy: 0.7361
# Epoch 38/100
# 20/20 [==============================] - 42s 2s/step - loss: 7.7018 - accuracy: 0.9837 - val_loss: 8.4431 - val_accuracy: 0.7361
# Epoch 39/100
# 20/20 [==============================] - 43s 2s/step - loss: 7.6621 - accuracy: 0.9723 - val_loss: 8.2524 - val_accuracy: 0.7500
# Epoch 40/100
# 20/20 [==============================] - 43s 2s/step - loss: 7.5793 - accuracy: 0.9869 - val_loss: 8.2122 - val_accuracy: 0.7917
# Epoch 41/100
# 20/20 [==============================] - 44s 2s/step - loss: 7.5095 - accuracy: 0.9902 - val_loss: 8.2215 - val_accuracy: 0.7917
# Epoch 42/100
# 20/20 [==============================] - 42s 2s/step - loss: 7.4779 - accuracy: 0.9821 - val_loss: 8.1409 - val_accuracy: 0.7222
# Epoch 43/100
# 20/20 [==============================] - 42s 2s/step - loss: 7.4227 - accuracy: 0.9853 - val_loss: 8.0160 - val_accuracy: 0.7639
# Epoch 44/100
# 20/20 [==============================] - 44s 2s/step - loss: 7.3556 - accuracy: 0.9869 - val_loss: 7.9475 - val_accuracy: 0.7500
# Epoch 45/100
# 20/20 [==============================] - 44s 2s/step - loss: 7.3194 - accuracy: 0.9821 - val_loss: 8.0148 - val_accuracy: 0.7222
# Epoch 46/100
# 20/20 [==============================] - 44s 2s/step - loss: 7.2836 - accuracy: 0.9723 - val_loss: 8.1307 - val_accuracy: 0.6667
# Epoch 47/100
# 20/20 [==============================] - 44s 2s/step - loss: 7.2035 - accuracy: 0.9821 - val_loss: 7.9612 - val_accuracy: 0.7222
# Epoch 48/100
# 20/20 [==============================] - 43s 2s/step - loss: 7.1369 - accuracy: 0.9902 - val_loss: 7.8309 - val_accuracy: 0.7639
# Epoch 49/100
# 20/20 [==============================] - 45s 2s/step - loss: 7.0863 - accuracy: 0.9918 - val_loss: 7.9669 - val_accuracy: 0.6944
# Epoch 50/100
# 20/20 [==============================] - 45s 2s/step - loss: 7.0458 - accuracy: 0.9837 - val_loss: 7.8375 - val_accuracy: 0.7083
# Epoch 51/100
# 20/20 [==============================] - 44s 2s/step - loss: 6.9849 - accuracy: 0.9967 - val_loss: 7.7871 - val_accuracy: 0.7500
# Epoch 52/100
# 20/20 [==============================] - 42s 2s/step - loss: 6.9294 - accuracy: 0.9902 - val_loss: 7.6748 - val_accuracy: 0.7500
# Epoch 53/100
# 20/20 [==============================] - 43s 2s/step - loss: 6.8615 - accuracy: 0.9967 - val_loss: 7.5770 - val_accuracy: 0.7361
# Epoch 54/100
# 20/20 [==============================] - 43s 2s/step - loss: 6.8178 - accuracy: 0.9951 - val_loss: 7.4910 - val_accuracy: 0.7639
# Epoch 55/100
# 20/20 [==============================] - 44s 2s/step - loss: 6.7676 - accuracy: 0.9951 - val_loss: 7.4236 - val_accuracy: 0.7917
# Epoch 56/100
# 20/20 [==============================] - 43s 2s/step - loss: 6.7139 - accuracy: 0.9951 - val_loss: 7.4465 - val_accuracy: 0.8056
# Epoch 57/100
# 20/20 [==============================] - 43s 2s/step - loss: 6.6644 - accuracy: 0.9951 - val_loss: 7.4286 - val_accuracy: 0.7778
# Epoch 58/100
# 20/20 [==============================] - 44s 2s/step - loss: 6.6108 - accuracy: 0.9951 - val_loss: 7.3603 - val_accuracy: 0.7639
# Epoch 59/100
# 20/20 [==============================] - 44s 2s/step - loss: 6.5606 - accuracy: 0.9935 - val_loss: 7.3239 - val_accuracy: 0.7778
# Epoch 60/100
# 20/20 [==============================] - 45s 2s/step - loss: 6.5070 - accuracy: 0.9951 - val_loss: 7.2605 - val_accuracy: 0.7778
# Epoch 61/100
# 20/20 [==============================] - 45s 2s/step - loss: 6.4434 - accuracy: 1.0000 - val_loss: 7.2013 - val_accuracy: 0.8056
# Epoch 62/100
# 20/20 [==============================] - 45s 2s/step - loss: 6.4079 - accuracy: 0.9918 - val_loss: 7.1519 - val_accuracy: 0.7778
# Epoch 63/100
# 20/20 [==============================] - 44s 2s/step - loss: 6.3479 - accuracy: 0.9984 - val_loss: 7.0940 - val_accuracy: 0.7778
# Epoch 64/100
# 20/20 [==============================] - 44s 2s/step - loss: 6.3140 - accuracy: 0.9886 - val_loss: 6.9715 - val_accuracy: 0.7361
# Epoch 65/100
# 20/20 [==============================] - 45s 2s/step - loss: 6.2539 - accuracy: 0.9935 - val_loss: 6.9218 - val_accuracy: 0.7361
# Epoch 66/100
# 20/20 [==============================] - 44s 2s/step - loss: 6.1947 - accuracy: 0.9967 - val_loss: 6.8580 - val_accuracy: 0.7500
# Epoch 67/100
# 20/20 [==============================] - 43s 2s/step - loss: 6.1546 - accuracy: 0.9918 - val_loss: 6.8076 - val_accuracy: 0.7639
# Epoch 68/100
# 20/20 [==============================] - 42s 2s/step - loss: 6.0959 - accuracy: 0.9967 - val_loss: 6.7827 - val_accuracy: 0.7778
# Epoch 69/100
# 20/20 [==============================] - 43s 2s/step - loss: 6.0710 - accuracy: 0.9902 - val_loss: 6.9759 - val_accuracy: 0.6806
# Epoch 70/100
# 20/20 [==============================] - 43s 2s/step - loss: 6.0196 - accuracy: 0.9935 - val_loss: 6.8479 - val_accuracy: 0.7778
# Epoch 71/100
# 20/20 [==============================] - 44s 2s/step - loss: 5.9623 - accuracy: 0.9951 - val_loss: 6.8353 - val_accuracy: 0.7778
# Epoch 72/100
# 20/20 [==============================] - 41s 2s/step - loss: 5.9170 - accuracy: 0.9918 - val_loss: 6.6901 - val_accuracy: 0.8056
# Epoch 73/100
# 20/20 [==============================] - 43s 2s/step - loss: 5.8753 - accuracy: 0.9902 - val_loss: 6.5978 - val_accuracy: 0.7917
# Epoch 74/100
# 20/20 [==============================] - 42s 2s/step - loss: 5.8688 - accuracy: 0.9821 - val_loss: 6.5381 - val_accuracy: 0.8194
# Epoch 75/100
# 20/20 [==============================] - 42s 2s/step - loss: 5.8196 - accuracy: 0.9821 - val_loss: 6.3419 - val_accuracy: 0.8333
# Epoch 76/100
# 20/20 [==============================] - 43s 2s/step - loss: 5.7677 - accuracy: 0.9804 - val_loss: 6.3407 - val_accuracy: 0.8194
# Epoch 77/100
# 20/20 [==============================] - 43s 2s/step - loss: 5.7106 - accuracy: 0.9918 - val_loss: 6.3114 - val_accuracy: 0.7917
# Epoch 78/100
# 20/20 [==============================] - 44s 2s/step - loss: 5.6501 - accuracy: 0.9967 - val_loss: 6.2422 - val_accuracy: 0.8056
# Epoch 79/100
# 20/20 [==============================] - 43s 2s/step - loss: 5.6328 - accuracy: 0.9902 - val_loss: 6.2507 - val_accuracy: 0.8056
# Epoch 80/100
# 20/20 [==============================] - 42s 2s/step - loss: 5.6101 - accuracy: 0.9869 - val_loss: 6.3559 - val_accuracy: 0.7500
# Epoch 81/100
# 20/20 [==============================] - 43s 2s/step - loss: 5.5437 - accuracy: 0.9951 - val_loss: 6.0971 - val_accuracy: 0.7917
# Epoch 82/100
# 20/20 [==============================] - 41s 2s/step - loss: 5.4966 - accuracy: 0.9853 - val_loss: 5.9901 - val_accuracy: 0.8194
# Epoch 83/100
# 20/20 [==============================] - 42s 2s/step - loss: 5.4570 - accuracy: 0.9886 - val_loss: 6.0474 - val_accuracy: 0.7917
# Epoch 84/100
# 20/20 [==============================] - 43s 2s/step - loss: 5.4384 - accuracy: 0.9804 - val_loss: 6.1651 - val_accuracy: 0.7778
# Epoch 85/100
# 20/20 [==============================] - 42s 2s/step - loss: 5.3946 - accuracy: 0.9902 - val_loss: 6.0461 - val_accuracy: 0.7778
# Epoch 86/100
# 20/20 [==============================] - 43s 2s/step - loss: 5.3313 - accuracy: 0.9918 - val_loss: 6.0707 - val_accuracy: 0.7778
# Epoch 87/100
# 20/20 [==============================] - 42s 2s/step - loss: 5.2882 - accuracy: 0.9935 - val_loss: 5.9578 - val_accuracy: 0.7917
# Epoch 88/100
# 20/20 [==============================] - 42s 2s/step - loss: 5.2379 - accuracy: 0.9967 - val_loss: 5.9132 - val_accuracy: 0.8056
# Epoch 89/100
# 20/20 [==============================] - 42s 2s/step - loss: 5.1950 - accuracy: 0.9951 - val_loss: 5.8817 - val_accuracy: 0.7917
# Epoch 90/100
# 20/20 [==============================] - 43s 2s/step - loss: 5.1559 - accuracy: 0.9935 - val_loss: 5.8318 - val_accuracy: 0.7917
# Epoch 91/100
# 20/20 [==============================] - 42s 2s/step - loss: 5.1199 - accuracy: 0.9935 - val_loss: 5.9201 - val_accuracy: 0.7500
# Epoch 92/100
# 20/20 [==============================] - 42s 2s/step - loss: 5.0746 - accuracy: 0.9951 - val_loss: 5.8743 - val_accuracy: 0.7778
# Epoch 93/100
# 20/20 [==============================] - 43s 2s/step - loss: 5.0467 - accuracy: 0.9951 - val_loss: 5.8162 - val_accuracy: 0.7639
# Epoch 94/100
# 20/20 [==============================] - 42s 2s/step - loss: 5.0023 - accuracy: 0.9951 - val_loss: 5.7255 - val_accuracy: 0.8194
# Epoch 95/100
# 20/20 [==============================] - 42s 2s/step - loss: 4.9658 - accuracy: 0.9935 - val_loss: 5.6508 - val_accuracy: 0.8194
# Epoch 96/100
# 20/20 [==============================] - 44s 2s/step - loss: 4.9110 - accuracy: 0.9984 - val_loss: 5.5956 - val_accuracy: 0.8056
# Epoch 97/100
# 20/20 [==============================] - 44s 2s/step - loss: 4.8790 - accuracy: 0.9935 - val_loss: 5.5693 - val_accuracy: 0.8333
# Epoch 98/100
# 20/20 [==============================] - 41s 2s/step - loss: 4.8313 - accuracy: 0.9967 - val_loss: 5.5196 - val_accuracy: 0.8194
# Epoch 99/100
# 20/20 [==============================] - 41s 2s/step - loss: 4.7956 - accuracy: 0.9935 - val_loss: 5.5181 - val_accuracy: 0.8056
# Epoch 100/100
# 20/20 [==============================] - 44s 2s/step - loss: 4.7649 - accuracy: 0.9984 - val_loss: 5.5105 - val_accuracy: 0.8056

# %%
plt.plot(history.history["loss"])
plt.plot(history.history["val_loss"])
plt.title("Model Categorical Cross Entropy")
plt.ylabel("Categorical Cross Entropy")
plt.xlabel("Epochs")
plt.legend(["train", "validation"], loc = "upper left")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.plot(history.history["accuracy"])
plt.plot(history.history["val_accuracy"])
plt.title("Model Accuracy")
plt.ylabel("Accuracy")
plt.xlabel("Epochs")
plt.legend(["train", "validation"], loc = "upper left")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
